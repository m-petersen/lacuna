# %% [markdown]
# # Functional network mapping
#
# In this tutorial, you will explore the functional network mapping functionalities of Lacuna using the CLI.
#
# **What you'll learn**:
#
# - Fetch a functional connectome
# - Obtain voxel-level lesion network maps
# - Compute ROI-wise lesion network scores
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/m-petersen/lacuna/blob/main/docs/tutorials/functional-network-mapping.ipynb)

# %% [markdown]
# ## Colab
#
# Note: Colab provides limited computational resources. While these tutorials are designed to operate within those constraints, some Lacuna functionality cannot be fully demonstrated in this environment and requires access to higher-performance computing infrastructure.
#
# Ignore this if you run this notebook locally.

# %% [markdown]
# ## Setup

# %%
# Install Lacuna from GitHub
# !pip install git+https://github.com/m-petersen/lacuna

# Install yabplot and pyvista for visualization
# !pip install yabplot pyvista==0.47.1
# Out:
# Collecting git+https://github.com/m-petersen/lacuna
#   Cloning https://github.com/m-petersen/lacuna to /tmp/pip-req-build-t4djkawd
#   Running command git clone --filter=blob:none --quiet https://github.com/m-petersen/lacuna /tmp/pip-req-build-t4djkawd
#   Resolved https://github.com/m-petersen/lacuna to commit ed7a40ef0420ce38e5e8f5da9b2192536f73274e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: nibabel>=5.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (5.3.2)
# Requirement already satisfied: numpy>=1.24 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (2.2.6)
# Requirement already satisfied: scipy>=1.10 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (1.15.3)
# Requirement already satisfied: nilearn>=0.10 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (0.12.1)
# Requirement already satisfied: pandas>=2.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (2.3.3)
# Requirement already satisfied: pooch>=1.8 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (1.8.2)
# Requirement already satisfied: h5py>=3.10 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (3.15.1)
# Requirement already satisfied: tqdm>=4.66 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (4.67.1)
# Requirement already satisfied: joblib>=1.3 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (1.5.2)
# Requirement already satisfied: nitransforms>=23.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (25.1.0)
# Requirement already satisfied: templateflow>=23.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (25.1.1)
# Requirement already satisfied: pyyaml>=6.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (6.0.3)
# Requirement already satisfied: requests>=2.31 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from lacuna==0.0.1.dev369) (2.32.5)
# Requirement already satisfied: importlib-resources>=5.12 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from nibabel>=5.0->lacuna==0.0.1.dev369) (6.5.2)
# Requirement already satisfied: packaging>=20 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from nibabel>=5.0->lacuna==0.0.1.dev369) (25.0)
# Requirement already satisfied: typing-extensions>=4.6 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from nibabel>=5.0->lacuna==0.0.1.dev369) (4.15.0)
# Requirement already satisfied: lxml in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from nilearn>=0.10->lacuna==0.0.1.dev369) (6.0.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from nilearn>=0.10->lacuna==0.0.1.dev369) (1.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pandas>=2.0->lacuna==0.0.1.dev369) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pandas>=2.0->lacuna==0.0.1.dev369) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pandas>=2.0->lacuna==0.0.1.dev369) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pooch>=1.8->lacuna==0.0.1.dev369) (4.5.0)
# Requirement already satisfied: six>=1.5 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->lacuna==0.0.1.dev369) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from requests>=2.31->lacuna==0.0.1.dev369) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from requests>=2.31->lacuna==0.0.1.dev369) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from requests>=2.31->lacuna==0.0.1.dev369) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from requests>=2.31->lacuna==0.0.1.dev369) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from scikit-learn>=1.4.0->nilearn>=0.10->lacuna==0.0.1.dev369) (3.6.0)
# Requirement already satisfied: acres>=0.5.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from templateflow>=23.0->lacuna==0.0.1.dev369) (0.5.0)
# Requirement already satisfied: pybids>=0.15.2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from templateflow>=23.0->lacuna==0.0.1.dev369) (0.21.0)
# Requirement already satisfied: formulaic>=0.3 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (1.2.1)
# Requirement already satisfied: sqlalchemy>=1.4.31 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (2.0.44)
# Requirement already satisfied: bids-validator>=1.14.7 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (1.14.7.post0)
# Requirement already satisfied: num2words>=0.5.10 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (0.5.14)
# Requirement already satisfied: click>=8.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (8.3.0)
# Requirement already satisfied: universal_pathlib>=0.2.2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (0.3.6)
# Requirement already satisfied: frozendict>=2.3 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (2.4.7)
# Requirement already satisfied: bidsschematools>=0.10 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from bids-validator>=1.14.7->pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (1.1.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from formulaic>=0.3->pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from formulaic>=0.3->pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (2.11.0)
# Requirement already satisfied: wrapt>=1.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from formulaic>=0.3->pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (2.0.1)
# Requirement already satisfied: docopt>=0.6.2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from num2words>=0.5.10->pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (0.6.2)
# Requirement already satisfied: greenlet>=1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from sqlalchemy>=1.4.31->pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (3.2.4)
# Requirement already satisfied: fsspec>=2024.5.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from universal_pathlib>=0.2.2->pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (2025.10.0)
# Requirement already satisfied: pathlib-abc<0.6.0,>=0.5.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from universal_pathlib>=0.2.2->pybids>=0.15.2->templateflow>=23.0->lacuna==0.0.1.dev369) (0.5.2)
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# Warning: 2 possible package resolutions (only showing differing packages):
#   - mrtrix3/linux-64::mrtrix3-3.0.8-h07fc403_0
#   - MRtrix3/linux-64::mrtrix3-3.0.8-h07fc403done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Requirement already satisfied: yabplot in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (0.2.2)
# Requirement already satisfied: ipywidgets>=8.1.8 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from yabplot) (8.1.8)
# Requirement already satisfied: nibabel>=5.3.2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from yabplot) (5.3.2)
# Requirement already satisfied: pandas>=2.3.3 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from yabplot) (2.3.3)
# Requirement already satisfied: pooch>=1.8.2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from yabplot) (1.8.2)
# Requirement already satisfied: pyvista>=0.46.4 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from yabplot) (0.47.1)
# Requirement already satisfied: scikit-image>=0.25.2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from yabplot) (0.25.2)
# Requirement already satisfied: trame>=3.12.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from yabplot) (3.12.0)
# Requirement already satisfied: trame-vtk>=2.10.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from yabplot) (2.11.3)
# Requirement already satisfied: trame-vuetify>=3.1.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from yabplot) (3.2.1)
# Requirement already satisfied: comm>=0.1.3 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipywidgets>=8.1.8->yabplot) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipywidgets>=8.1.8->yabplot) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipywidgets>=8.1.8->yabplot) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipywidgets>=8.1.8->yabplot) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipywidgets>=8.1.8->yabplot) (3.0.16)
# Requirement already satisfied: decorator in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (5.2.1)
# Requirement already satisfied: exceptiongroup in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (2.19.2)
# Requirement already satisfied: stack_data in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (4.15.0)
# Requirement already satisfied: wcwidth in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (0.8.5)
# Requirement already satisfied: importlib-resources>=5.12 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from nibabel>=5.3.2->yabplot) (6.5.2)
# Requirement already satisfied: numpy>=1.22 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from nibabel>=5.3.2->yabplot) (2.2.6)
# Requirement already satisfied: packaging>=20 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from nibabel>=5.3.2->yabplot) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pandas>=2.3.3->yabplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pandas>=2.3.3->yabplot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pandas>=2.3.3->yabplot) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pooch>=1.8.2->yabplot) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pooch>=1.8.2->yabplot) (2.32.5)
# Requirement already satisfied: six>=1.5 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.3.3->yabplot) (1.17.0)
# Requirement already satisfied: cyclopts>=4.0.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pyvista>=0.46.4->yabplot) (4.10.0)
# Requirement already satisfied: matplotlib>=3.0.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pyvista>=0.46.4->yabplot) (3.10.7)
# Requirement already satisfied: pillow in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pyvista>=0.46.4->yabplot) (12.0.0)
# Requirement already satisfied: scooby>=0.5.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pyvista>=0.46.4->yabplot) (0.11.0)
# Requirement already satisfied: vtk!=9.4.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from pyvista>=0.46.4->yabplot) (9.3.1)
# Requirement already satisfied: attrs>=23.1.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from cyclopts>=4.0.0->pyvista>=0.46.4->yabplot) (25.4.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from cyclopts>=4.0.0->pyvista>=0.46.4->yabplot) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from cyclopts>=4.0.0->pyvista>=0.46.4->yabplot) (1.3.2)
# Requirement already satisfied: rich>=13.6.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from cyclopts>=4.0.0->pyvista>=0.46.4->yabplot) (14.3.3)
# Requirement already satisfied: tomli>=2.0.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from cyclopts>=4.0.0->pyvista>=0.46.4->yabplot) (2.3.0)
# Requirement already satisfied: docutils in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->pyvista>=0.46.4->yabplot) (0.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.46.4->yabplot) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.46.4->yabplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.46.4->yabplot) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.46.4->yabplot) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from matplotlib>=3.0.1->pyvista>=0.46.4->yabplot) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.8.2->yabplot) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.8.2->yabplot) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.8.2->yabplot) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.8.2->yabplot) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from rich>=13.6.0->cyclopts>=4.0.0->pyvista>=0.46.4->yabplot) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.6.0->cyclopts>=4.0.0->pyvista>=0.46.4->yabplot) (0.1.2)
# Requirement already satisfied: scipy>=1.11.4 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from scikit-image>=0.25.2->yabplot) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from scikit-image>=0.25.2->yabplot) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from scikit-image>=0.25.2->yabplot) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from scikit-image>=0.25.2->yabplot) (2025.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from scikit-image>=0.25.2->yabplot) (0.5)
# Requirement already satisfied: trame-server<4,>=3.4 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from trame>=3.12.0->yabplot) (3.10.0)
# Requirement already satisfied: trame-client<4,>=3.10.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from trame>=3.12.0->yabplot) (3.11.3)
# Requirement already satisfied: trame-common<2,>=1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from trame>=3.12.0->yabplot) (1.1.3)
# Requirement already satisfied: wslink>=2.3.3 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from trame>=3.12.0->yabplot) (2.5.6)
# Requirement already satisfied: pyyaml in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from trame>=3.12.0->yabplot) (6.0.3)
# Requirement already satisfied: more-itertools in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from trame-server<4,>=3.4->trame>=3.12.0->yabplot) (10.8.0)
# Requirement already satisfied: aiohttp<4 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from wslink>=2.3.3->trame>=3.12.0->yabplot) (3.13.3)
# Requirement already satisfied: msgpack<2,>=1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from wslink>=2.3.3->trame>=3.12.0->yabplot) (1.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from aiohttp<4->wslink>=2.3.3->trame>=3.12.0->yabplot) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from aiohttp<4->wslink>=2.3.3->trame>=3.12.0->yabplot) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from aiohttp<4->wslink>=2.3.3->trame>=3.12.0->yabplot) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from aiohttp<4->wslink>=2.3.3->trame>=3.12.0->yabplot) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from aiohttp<4->wslink>=2.3.3->trame>=3.12.0->yabplot) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from aiohttp<4->wslink>=2.3.3->trame>=3.12.0->yabplot) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from aiohttp<4->wslink>=2.3.3->trame>=3.12.0->yabplot) (1.23.0)
# Requirement already satisfied: executing>=1.2.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (3.0.0)
# Requirement already satisfied: pure_eval in /home/marvin/miniconda3/envs/lacuna/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.8->yabplot) (0.2.3)

# %% [markdown]
# Get the tutorial data.

# %%
# Get tutorial data
# !lacuna tutorial /tmp/tutorial_bids --force
# Out:
# Setting up tutorial data at: /tmp/tutorial_bids
# ✓ Tutorial data copied to: /tmp/tutorial_bids
#
# The tutorial dataset includes:
#   - 3 synthetic subjects (sub-01, sub-02, sub-03)
#   - Binary lesion masks in MNI152NLin6Asym space
#   - BIDS-compliant structure

# %% [markdown]
# ## Fetch functional connectome

# %% [markdown]
# Functional lesion network mapping requires a functional connectome in the form of resting-state functional MR images of a normative cohort.
#
# Lacuna facilitates to download the [GSP1000 dataset](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/ILXIKS) which is openly available and the current standard. For the download you have to obtain an access token. For this register on [Harvard Dataverse](https://dataverse.harvard.edu/), click on your username and then API Token.
#
# Here, we will only fetch a test version of GSP1000 to keep the tutorial lightweight via the `--test-mode` flag. You should remove the flag for an actual analysis. Please mind that the original dataset comprises ~200gb of data so you need space for that. To maximize processing efficiency, store the connectome on an SSD.

# %%
# !lacuna fetch gsp1000 \
    --output-dir /tmp/gsp1000_data \
    --api-key $DATAVERSE_API_KEY \
    --test-mode \
    --skip-checksum \
    --no-keep-original
# Out:
# Fetching GSP1000 functional connectome...
#   Output: /tmp/gsp1000_data
#   Mode: TEST (1 tarball only)
#   Warning: Checksum verification disabled
#
#
# ✓ GSP1000 fetch complete!
#   Files: 1
#   Duration: 0.0s
#   Output: /tmp/gsp1000_data/processed

# %% [markdown]
# ## Analysis
#
# Functional lesion network mapping seeks to identify the functional brain circuitry connecting to the lesion. Based on the connectome the average functional connectivity between the lesion and every voxel in the connectome space is quantified.
#
# Lacuna's implementation consists of multiple steps:
# 1. Ensure spatial alignment.
# 2. Compute the lesion timeseries.
# 3. Compute voxel-wise statistics: Pearson correlations between the lesion timeseries and whole-brain timeseries, Fisher z, t-statistics, and optionally p-value maps and FDR-corrected p-values (Benjamini–Hochberg) and thresholded significance maps.
# 4. Export results as NIfTI VoxelMaps (rmap, zmap, tmap, pmap, FDR-corrected pmap, threshold masks).
#
# You can adapt the analysis with different parameters including the choice between the original method implemented by [Boes, Fox et al.](https://doi.org/10.1093/brain/awv228) as well as by [Pini et al.](https://doi.org/10.1093/braincomms/fcab259) By default the analysis uses the former.

# %% [markdown]
# Run the analysis.

# %%
# !lacuna run fnm \
    /tmp/tutorial_bids/ \
    /tmp/outputs_fnm/ \
    --connectome-path /tmp/gsp1000_data/processed/ \
    --participant-label 01 \
    --mask-space MNI152NLin6Asym

# %% [markdown]
# Visualize the output

# %%
import nibabel as nib
from nilearn import plotting

tmap_path = '/tmp/outputs_fnm/sub-01/ses-01/anat/sub-01_ses-01_label-acuteinfarct_method-fnm_space-MNI152NLin6Asym_desc-tmap.nii.gz'
tmap_img = nib.load(tmap_path)

plotting.plot_stat_map(tmap_img, 
                       radiological=True, 
                       title="T-statistic map from FNM",
                       draw_cross=False, 
                       colorbar=True,
                       cmap='seismic',
                       vmin=-5,
                       vmax=5
                       )

# %% [markdown]
# The map looks a bit speckled but this is expected due to only a small fraction of connectome subjects being considered in this test run. Once the full connectome is used the map will be smoother.

# %% [markdown]
# ## Obtain parcel-level lesion network scores

# %% [markdown]
# Beyond voxel-level maps, Lacuna can aggregate the signal in atlas parcels. An atlas can be specified via `--parcel-atlases`. The argument also takes multiple atlases.

# %%
# !lacuna run fnm \
    /tmp/tutorial_bids/ \
    /tmp/outputs_fnm/ \
    --connectome-path /tmp/gsp1000_data/processed/ \
    --participant-label 01 \
    --mask-space MNI152NLin6Asym \
    --parcel-atlases schaefer2018parcels200networks7 schaefer2018parcels400networks7 \
    --verbose

# %%
# !ls /tmp/outputs_fnm/sub-01/ses-01/anat/
# Out:
# sub-01_ses-01_desc-provenance.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels100networks7_method-fnm_desc-rmap_parcelstats.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels100networks7_method-fnm_desc-rmap_parcelstats.tsv
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels100networks7_method-fnm_desc-tmap_parcelstats.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels100networks7_method-fnm_desc-tmap_parcelstats.tsv
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels100networks7_method-fnm_desc-zmap_parcelstats.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels100networks7_method-fnm_desc-zmap_parcelstats.tsv
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels200networks7_method-fnm_desc-rmap_parcelstats.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels200networks7_method-fnm_desc-rmap_parcelstats.tsv
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels200networks7_method-fnm_desc-tmap_parcelstats.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels200networks7_method-fnm_desc-tmap_parcelstats.tsv
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels200networks7_method-fnm_desc-zmap_parcelstats.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels200networks7_method-fnm_desc-zmap_parcelstats.tsv
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels400networks7_method-fnm_desc-rmap_parcelstats.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels400networks7_method-fnm_desc-rmap_parcelstats.tsv
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels400networks7_method-fnm_desc-tmap_parcelstats.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels400networks7_method-fnm_desc-tmap_parcelstats.tsv
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels400networks7_method-fnm_desc-zmap_parcelstats.json
# sub-01_ses-01_label-acuteinfarct_atlas-schaefer2018parcels400networks7_method-fnm_desc-zmap_parcelstats.tsv
# sub-01_ses-01_label-acuteinfarct_summarystatistics_stats.json
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-pfdrmap.json
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-pfdrmap.nii.gz
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-pfdrthresholdmap.json
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-pfdrthresholdmap.nii.gz
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-pmap.json
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-pmap.nii.gz
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-rmap.json
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-rmap.nii.gz
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-tmap.json
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-tmap.nii.gz
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-zmap.json
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_method-fnm_desc-zmap.nii.gz
# sub-01_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_mask.nii.gz

# %% [markdown]
# Visualize the parcel-level lesion network scores on the cortical surface with [yabplot](https://teanijarv.github.io/yabplot/)

# %%
import warnings
import pandas as pd
import pyvista as pv
import yabplot as yab

warnings.simplefilter("ignore", pv.PyVistaDeprecationWarning)

pv.set_jupyter_backend('static')
pv.global_theme.notebook = True
pv.start_xvfb()

file_path = "/tmp/outputs_fnm/sub-01/ses-01/anat/sub-01_ses-01_label-acuteinfarct_method-fnm_atlas-schaefer2018parcels400networks7_desc-rmap_parcelstats.tsv"

df = pd.read_csv(file_path, sep="\t", index_col=0)
values = df.values.flatten()

yab.plot_cortical(
    data=values,
    atlas='schaefer_400',
    views=['left_lateral', 'left_medial', 'right_lateral', 'right_medial'],
    figsize=(800, 300),
    vminmax=(-0.2,0.2),
    cmap="RdBu_r",
    display_type="static",
)
# Out:
# <PIL.Image.Image image mode=RGB size=800x300>

# %% [markdown]
# ## Run functional network mapping on multiple subjects
# Lacuna supports processing multiple subjects within a single run. If the `--participant-label` flag is omitted, the pipeline automatically executes for all subjects detected in the BIDS dataset. Using `--verbose` enables inspection of the detected lesion masks.
#
# Execution strategies are internally optimized per analysis type. For functional network mapping, subjects are processed in parallel, and multi-subject computation is implemented via vectorization. This improves throughput but has implications for memory usage.
#
# These optimizations allow large cohorts to be processed efficiently with relatively modest computational overhead. However, RAM consumption scales with the number of subjects and should be monitored accordingly.
#
# Internally, Lacuna loads batches of lesion masks alongside batches of resting-state fMRI data from the connectome, which together determine memory usage. Resource demands can be controlled in two ways: (1) limiting the number of lesion masks processed simultaneously via `lacuna run fnm (...) --batch-size <N>`, and (2) changing the connectome batch number during retrieval using `lacuna fetch GSP1000 (...) --batches <N>` (more batches ⟶ less size per batch ⟶ less memory demands).
#
# For demonstration purposes, replicate the first tutorial subject to create a dataset of 40 subjects instead of 3.

# %%
import shutil
from pathlib import Path

tutorial_data = Path("/tmp/tutorial_bids")
tutorial_data_multiple = Path("/tmp/tutorial_bids_multiple")


src_id = "01"
src_file = tutorial_data / f"sub-{src_id}" / "ses-01" / "anat" / f"sub-{src_id}_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_mask.nii.gz"

for i in range(0, 40):

    sub_id = f"{i+1:02d}"
    
    target_dir = tutorial_data_multiple / f"sub-{sub_id}" / "ses-01" / "anat"
    target_file = target_dir / f"sub-{sub_id}_ses-01_space-MNI152NLin6Asym_label-acuteinfarct_mask.nii.gz"
    
    target_dir.mkdir(parents=True, exist_ok=True)
    
    shutil.copy2(src_file, target_file)

# %%
# !ls /tmp/tutorial_bids_multiple/
# Out:
# sub-01	sub-05	sub-09	sub-13	sub-17	sub-21	sub-25	sub-29	sub-33	sub-37
# sub-02	sub-06	sub-10	sub-14	sub-18	sub-22	sub-26	sub-30	sub-34	sub-38
# sub-03	sub-07	sub-11	sub-15	sub-19	sub-23	sub-27	sub-31	sub-35	sub-39
# sub-04	sub-08	sub-12	sub-16	sub-20	sub-24	sub-28	sub-32	sub-36	sub-40

# %% [markdown]
# Run the analysis on the whole dataset in participant batches of n = 10.

# %%
# !lacuna run fnm \
    /tmp/tutorial_bids_multiple/ \
    /tmp/outputs_fnm_multiple/ \
    --connectome-path /tmp/gsp1000_data/processed/ \
    --mask-space MNI152NLin6Asym \
    --batch-size 10 \
    --nprocs -1 \
    --verbose

# %%
# !ls /tmp/outputs_fnm_multiple
# Out:
# dataset_description.json  sub-06  sub-12  sub-18  sub-24  sub-30  sub-36
# sub-01			  sub-07  sub-13  sub-19  sub-25  sub-31  sub-37
# sub-02			  sub-08  sub-14  sub-20  sub-26  sub-32  sub-38
# sub-03			  sub-09  sub-15  sub-21  sub-27  sub-33  sub-39
# sub-04			  sub-10  sub-16  sub-22  sub-28  sub-34
# sub-05			  sub-11  sub-17  sub-23  sub-29  sub-35
